# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
df =pd.read_csv("/content/drive/MyDrive/ML/marks123 - Sheet1.csv")
print("Original Dataset:")
print(df)
# Out:
# Original Dataset:
#      Name   Roll Number   TELUGU  HINDI  ENGLISH  SCIENCE  SOCIAL  MATHS
# 0      Roy             1    99.0   99.0     99.0    100.0    99.0    100
# 1     Sabi             2    79.0    NaN     54.0     78.0    78.0     89
# 2     Teju             3    28.0   25.0     75.0     98.0    45.0     56
# 3   Akhila             4    65.0   64.0     64.0     77.0    65.0     32
# 4     Aish             5    64.0   78.0      NaN     66.0    89.0     45
# 5    Vaish             6     NaN   69.0     87.0     55.0    32.0     73
# 6    Jaggu             7    45.0   64.0     37.0      NaN    45.0     91
# 7  Keerthi             8    56.0   67.0     28.0     98.0     NaN     61
# 8   Sindhu             9    55.0   64.0     67.0     75.0    56.0     43
# 9   Sindhu             9    55.0   64.0     67.0     75.0    56.0     43

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
scaler =StandardScaler()
numerical_features =df.select_dtypes(include =['float64','int64']).columns
df[numerical_features ] =scaler.fit_transform(df[numerical_features ])
print("Standardized Dataset :")
print(df)
# Out:
# Standardized Dataset :
#      Name   Roll Number     TELUGU     HINDI   ENGLISH   SCIENCE    SOCIAL  \
# 0      Roy     -1.613118  2.022217  1.825835  1.646047  1.350035  1.738376
# 1     Sabi     -1.246500  0.967147       NaN -0.483822 -0.151689  0.730545
# 2     Teju     -0.879883 -1.723281 -2.268462  0.510117  1.213515 -0.853191
# 3   Akhila     -0.513265  0.228598 -0.110657 -0.010518 -0.219950  0.106649
# 4     Aish     -0.146647  0.175845  0.663940       NaN -0.970812  1.258456
# 5    Vaish      0.219971       NaN  0.165985  1.078082 -1.721674 -1.477087
# 6    Jaggu      0.586588 -0.826471 -0.110657 -1.288439       NaN -0.853191
# 7  Keerthi      0.953206 -0.246183  0.055328 -1.714413  1.213515       NaN
# 8   Sindhu      1.319824 -0.298936 -0.110657  0.131473 -0.356470 -0.325279
# 9   Sindhu      1.319824 -0.298936 -0.110657  0.131473 -0.356470 -0.325279
#
#       MATHS
# 0  1.630531
# 1  1.141816
# 2 -0.324329
# 3 -1.390617
# 4 -0.813044
# 5  0.430958
# 6  1.230674
# 7 -0.102186
# 8 -0.901902
# 9 -0.901902
