# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df =pd.read_csv("/content/drive/MyDrive/ML/marks123 - Sheet1.csv")
summary_stats=df.describe()
print("\n Summary Statistics")
print(summary_stats)
# Out:
#  Summary Statistics
#        Roll Number      TELUGU     HINDI    ENGLISH     SCIENCE     SOCIAL  \
# count     10.000000   9.000000   9.00000   9.000000    9.000000   9.000000
# mean       5.400000  60.666667  66.00000  64.222222   80.222222  62.777778
# std        2.875181  20.105969  19.17029  22.409695   15.538483  22.100779
# min        1.000000  28.000000  25.00000  28.000000   55.000000  32.000000
# 25%        3.250000  55.000000  64.00000  54.000000   75.000000  45.000000
# 50%        5.500000  56.000000  64.00000  67.000000   77.000000  56.000000
# 75%        7.750000  65.000000  69.00000  75.000000   98.000000  78.000000
# max        9.000000  99.000000  99.00000  99.000000  100.000000  99.000000
#
#             MATHS
# count   10.000000
# mean    63.300000
# std     23.725514
# min     32.000000
# 25%     43.500000
# 50%     58.500000
# 75%     85.000000
# max    100.000000

# %%
plt.figure(figsize=(10,6))
df.hist(bins=10,figsize=(10,6))
plt.subplots_adjust(wspace=0.7)
plt.subplots_adjust(hspace=0.7)
plt.suptitle("Histograms")
plt.show()

# %%
plt.figure(figsize=(10,6))
df.plot(kind='box' ,subplots=True,layout =(1,len(df.columns)),figsize =(10,10))
plt.subplots_adjust(wspace=0.7)
plt.suptitle("Box Plots")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.pairplot(df)
plt.suptitle("Pair Plots ",y=1.02)
plt.show()
